# %% [markdown]
# ### high_value_orders_classification  and "Target Variable Investigation"

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay
)

# %%
original_df = pd.read_csv("../dataset/original_dataset/ecommerce_orders_dataset.csv")

# %%
original_df[["Order_Amount", "High_Value_Order"]].head()
# Out:
#    Order_Amount High_Value_Order
# 0         68.20               No
# 1         38.73               No
# 2        153.66               No
# 3        298.37               No
# 4        105.75               No

# %%
original_df.groupby("High_Value_Order")["Order_Amount"].describe()
# Out:
#                     count         mean         std     min     25%     50%  \
# High_Value_Order
# No                22499.0   144.255416   94.195631    6.67   67.40  120.19
# Yes                7501.0  1083.114437  826.429620  388.19  521.36  778.83
#
#                        75%       max
# High_Value_Order
# No                 205.365    388.17
# Yes               1353.810  10314.27

# %%
df = original_df.copy()

# %%
print(df.shape)
# Out:
# (30000, 41)

# %%
df.head(10)
# Out:
#    Order_ID Customer_ID  Order_Date  Year  Month  Day Day_Of_Week  Quarter  \
# 0    615717  CUST007322  2023-01-01  2023      1    1      Sunday        1
# 1    626919  CUST004717  2023-01-01  2023      1    1      Sunday        1
# 2    615781  CUST004415  2023-01-01  2023      1    1      Sunday        1
# 3    621747  CUST004114  2023-01-01  2023      1    1      Sunday        1
# 4    625881  CUST000145  2023-01-01  2023      1    1      Sunday        1
# 5    613497  CUST000940  2023-01-01  2023      1    1      Sunday        1
# 6    600746  CUST004139  2023-01-01  2023      1    1      Sunday        1
# 7    604774  CUST000543  2023-01-01  2023      1    1      Sunday        1
# 8    600323  CUST003309  2023-01-01  2023      1    1      Sunday        1
# 9    608449  CUST006419  2023-01-01  2023      1    1      Sunday        1
#
#    Customer_Age Customer_Gender  ... Delivery_Days Order_Status Returned  \
# 0            32            Male  ...             2    Delivered       No
# 1            50            Male  ...             9    Delivered       No
# 2            61            Male  ...             2    Delivered       No
# 3            34            Male  ...             6     Returned      Yes
# 4            37            Male  ...             8    Delivered       No
# 5            32          Female  ...             5   Processing       No
# 6            25          Female  ...             6    Delivered       No
# 7            38          Female  ...             6    Delivered       No
# 8            48          Female  ...             5    Delivered       No
# 9            31           Other  ...             6      Shipped       No
#
#   Review_Rating Customer_Lifetime_Value Profit_Margin_Percent Profit_Amount  \
# 0           4.4                 2144.92                 23.10         15.75
# 1           4.1                  817.17                  8.57          3.32
# 2           5.0                  541.16                 29.72         45.67
# 3           3.4                  700.49                 25.22         75.25
# 4           3.6                 2133.77                 24.64         26.06
# 5           4.1                 5844.78                 30.29        125.38
# 6           5.0                 1178.52                 27.91         32.45
# 7           4.1                 2535.68                 10.14         11.85
# 8           3.4                  598.88                 17.93         19.06
# 9           4.5                 1050.17                 31.95         59.20
#
#    Season  Holiday_Season  High_Value_Order
# 0  Winter              No                No
# 1  Winter              No                No
# 2  Winter              No                No
# 3  Winter              No                No
# 4  Winter              No                No
# 5  Winter              No               Yes
# 6  Winter              No                No
# 7  Winter              No                No
# 8  Winter              No                No
# 9  Winter              No                No
#
# [10 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order_ID                 30000 non-null  int64
#  1   Customer_ID              30000 non-null  str
#  2   Order_Date               30000 non-null  str
#  3   Year                     30000 non-null  int64
#  4   Month                    30000 non-null  int64
#  5   Day                      30000 non-null  int64
#  6   Day_Of_Week              30000 non-null  str
#  7   Quarter                  30000 non-null  int64
#  8   Customer_Age             30000 non-null  int64
#  9   Customer_Gender          30000 non-null  str
#  10  Country                  30000 non-null  str
#  11  City                     30000 non-null  str
#  12  Customer_Segment         30000 non-null  str
#  13  Product_ID               30000 non-null  str
#  14  Product_Category         30000 non-null  str
#  15  Product_Subcategory      30000 non-null  str
#  16  Brand                    30000 non-null  str
#  17  Unit_Price               30000 non-null  float64
#  18  Quantity                 30000 non-null  int64
#  19  Discount_Percent         30000 non-null  int64
#  20  Discount_Amount          30000 non-null  float64
#  21  Coupon_Used              30000 non-null  str
#  22  Shipping_Cost            30000 non-null  float64
#  23  Tax_Amount               30000 non-null  float64
#  24  Order_Amount             30000 non-null  float64
#  25  Payment_Method           30000 non-null  str
#  26  Device_Type              30000 non-null  str
#  27  Traffic_Source           30000 non-null  str
#  28  Membership_Status        30000 non-null  str
#  29  Shipping_Method          30000 non-null  str
#  30  Warehouse_Region         30000 non-null  str
#  31  Delivery_Days            30000 non-null  int64
#  32  Order_Status             30000 non-null  str
#  33  Returned                 30000 non-null  str
#  34  Review_Rating            30000 non-null  float64
#  35  Customer_Lifetime_Value  30000 non-null  float64
#  36  Profit_Margin_Percent    30000 non-null  float64
#  37  Profit_Amount            30000 non-null  float64
#  38  Season                   30000 non-null  str
#  39  Holiday_Season           30000 non-null  str
#  40  High_Value_Order         30000 non-null  str
# dtypes: float64(9), int64(9), str(23)
# memory usage: 13.8 MB

# %%
print(df["High_Value_Order"].value_counts())
# Out:
# High_Value_Order
# No     22499
# Yes     7501
# Name: count, dtype: int64

# %%
print(df["High_Value_Order"].value_counts(normalize=True)*100)
# Out:
# High_Value_Order
# No     74.996667
# Yes    25.003333
# Name: proportion, dtype: float64

# %%
df.isnull().sum()
# Out:
# Order_ID                   0
# Customer_ID                0
# Order_Date                 0
# Year                       0
# Month                      0
# Day                        0
# Day_Of_Week                0
# Quarter                    0
# Customer_Age               0
# Customer_Gender            0
# Country                    0
# City                       0
# Customer_Segment           0
# Product_ID                 0
# Product_Category           0
# Product_Subcategory        0
# Brand                      0
# Unit_Price                 0
# Quantity                   0
# Discount_Percent           0
# Discount_Amount            0
# Coupon_Used                0
# Shipping_Cost              0
# Tax_Amount                 0
# Order_Amount               0
# Payment_Method             0
# Device_Type                0
# Traffic_Source             0
# Membership_Status          0
# Shipping_Method            0
# Warehouse_Region           0
# Delivery_Days              0
# Order_Status               0
# Returned                   0
# Review_Rating              0
# Customer_Lifetime_Value    0
# Profit_Margin_Percent      0
# Profit_Amount              0
# Season                     0
# Holiday_Season             0
# High_Value_Order           0
# dtype: int64

# %%
df.drop(
    columns=[
        "Order_ID",
        "Customer_ID",
        "Product_ID",
        "Order_Amount",
        "Profit_Amount",
        "Profit_Margin_Percent"
    ],
    inplace=True
)

# %%
X = df.drop("High_Value_Order", axis=1)
y =df["High_Value_Order"]

# %%
categorical_cols = X.select_dtypes(include=["object"]).columns.tolist()
numerical_cols = X.select_dtypes(exclude=["object"]).columns.tolist()

print("Categorical Columns:", len(categorical_cols))
print("Numerical Columns", len(numerical_cols))
# Out:
# Categorical Columns: 20
# Numerical Columns 14
# C:\Users\srava\AppData\Local\Temp\ipykernel_9056\142581708.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = X.select_dtypes(include=["object"]).columns.tolist()

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "cat",
            OneHotEncoder(handle_unknown="ignore"),
            categorical_cols
        )
    ],
    remainder="passthrough"
)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y_encoded,          # use encoded labels
    test_size=0.20,
    stratify=y_encoded, # use encoded labels
    random_state=42
)

# %%
print(y_train.dtype)
print(np.unique(y_train))
# Out:
# int64
# [0 1]

# %%
rf_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),

        (
            "classifier",
            RandomForestClassifier(
                n_estimators=200,
                random_state=42
            )
        )
    ]
)

# %%
rf_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Order_Date', 'Day_Of_Week',
#                                                    'Customer_Gender', 'Country',
#                                                    'City', 'Customer_Segment',
#                                                    'Product_Category',
#                                                    'Product_Subcategory',
#                                                    'Brand', 'Coupon_Used',
#                                                    'Payment_Method',
#                                                    'Device_Type',
#                                                    'Traffic_Source',
#                                                    'Membership_Status',
#                                                    'Shipping_Method',
#                                                    'Warehouse_Region',
#                                                    'Order_Status', 'Returned',
#                                                    'Season',
#                                                    'Holiday_Season'])])),
#                 ('classifier',
#                  RandomForestClassifier(n_estimators=200, random_state=42))])

# %%
y_pred = rf_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.9700

# %%
cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=rf_model.classes_
)

disp.plot(cmap="Blues")

plt.title("Confusion Matrix")

plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4500
#            1       0.96      0.92      0.94      1500
#
#     accuracy                           0.97      6000
#    macro avg       0.97      0.95      0.96      6000
# weighted avg       0.97      0.97      0.97      6000

# %% [markdown]
# #### Importance

# %%
rf = rf_model.named_steps["classifier"]

# %%
feature_names = rf_model.named_steps["preprocessor"].get_feature_names_out()

# %%
importance = rf.feature_importances_

# %%
importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": importance
})

# %%
importance_df = importance_df.sort_values(
    by="Importance",
    ascending=False
)

importance_df.head(20)
# Out:
#                                    Feature  Importance
# 1598                 remainder__Tax_Amount    0.163214
# 1601    remainder__Customer_Lifetime_Value    0.149251
# 1593                 remainder__Unit_Price    0.138295
# 1497     cat__Product_Category_Electronics    0.089295
# 1596            remainder__Discount_Amount    0.065747
# 1594                   remainder__Quantity    0.026883
# 1503  cat__Product_Subcategory_Accessories    0.019573
# 1526       cat__Product_Subcategory_Mobile    0.019550
# 1523       cat__Product_Subcategory_Laptop    0.017598
# 1522   cat__Product_Subcategory_Headphones    0.017102
# 1499       cat__Product_Category_Groceries    0.014731
# 1500  cat__Product_Category_Home & Kitchen    0.011185
# 1597              remainder__Shipping_Cost    0.010629
# 1595           remainder__Discount_Percent    0.010246
# 1592               remainder__Customer_Age    0.006559
# 1600              remainder__Review_Rating    0.006054
# 1590                        remainder__Day    0.005975
# 1495          cat__Product_Category_Beauty    0.005597
# 1599              remainder__Delivery_Days    0.005396
# 1498         cat__Product_Category_Fashion    0.004804

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.barh(
    importance_df["Feature"].head(20),
    importance_df["Importance"].head(20)
)

plt.gca().invert_yaxis()

plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Top 20 Feature Importance")

plt.tight_layout()

# Optional: Save the graph
plt.savefig("feature_importance_exp2.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
original_df.groupby("High_Value_Order")["Order_Amount"].describe()
# Out:
#                     count         mean         std     min     25%     50%  \
# High_Value_Order
# No                22499.0   144.255416   94.195631    6.67   67.40  120.19
# Yes                7501.0  1083.114437  826.429620  388.19  521.36  778.83
#
#                        75%       max
# High_Value_Order
# No                 205.365    388.17
# Yes               1353.810  10314.27

# %% [markdown]
# #### dython

# %%
from dython.nominal import associations

associations(
    original_df,
    figsize=(20, 20),
    cmap="coolwarm",
    annot=True
)
# Out:
# {'corr':                          Order_ID  Customer_ID  Order_Date      Year  \
#  Order_ID                 1.000000     0.534290    0.224498 -0.003973
#  Customer_ID              0.534290     1.000000    0.000000  0.537928
#  Order_Date               0.224498     0.000000    1.000000  1.000000
#  Year                    -0.003973     0.537928    1.000000  1.000000
#  Month                   -0.008787     0.539673    1.000000  0.002944
#  Day                      0.002341     0.540463    1.000000 -0.010696
#  Day_Of_Week              0.010976     0.000000    0.975460  0.012240
#  Quarter                 -0.009870     0.539133    1.000000  0.003798
#  Customer_Age            -0.003918     0.534422    0.222876  0.002207
#  Customer_Gender          0.005985     0.041805    0.037254  0.003235
#  Country                  0.010533     0.017833    0.014103  0.012437
#  City                     0.021315     0.000000    0.000000  0.017500
#  Customer_Segment         0.011673     0.000000    0.029645  0.007934
#  Product_ID               0.290825     0.000000    0.007130  0.288988
#  Product_Category         0.013888     0.000000    0.031181  0.015025
#  Product_Subcategory      0.038517     0.027338    0.014596  0.035395
#  Brand                    0.018052     0.015663    0.000000  0.019223
#  Unit_Price              -0.000771     0.540580    0.226548 -0.004759
#  Quantity                -0.005851     0.538405    0.220322 -0.006454
#  Discount_Percent         0.005157     0.539816    0.215279  0.002006
#  Discount_Amount         -0.000379     0.556230    0.220621 -0.001654
#  Coupon_Used              0.002072     0.000000    0.000000  0.001072
#  Shipping_Cost           -0.003835     0.539284    0.218699 -0.002695
#  Tax_Amount              -0.002922     0.535977    0.223243 -0.007971
#  Order_Amount            -0.003024     0.539515    0.223193 -0.008116
#  Payment_Method           0.023802     0.026329    0.016271  0.016735
#  Device_Type              0.004304     0.029839    0.000000  0.005932
#  Traffic_Source           0.014887     0.000000    0.015579  0.008270
#  Membership_Status        0.013234     0.000000    0.000000  0.010762
#  Shipping_Method          0.012958     0.048267    0.000000  0.003585
#  Warehouse_Region         0.003962     0.025348    0.000000  0.005917
#  Delivery_Days           -0.003359     0.541616    0.218229 -0.004446
#  Order_Status             0.007944     0.000000    0.017744  0.007705
#  Returned                 0.006681     0.000000    0.019307  0.001243
#  Review_Rating            0.002797     0.536293    0.225337  0.005233
#  Customer_Lifetime_Value -0.005001     0.538885    0.224832 -0.006689
#  Profit_Margin_Percent   -0.005124     0.538563    0.217817 -0.008499
#  Profit_Amount           -0.005518     0.554689    0.221964 -0.011831
#  Season                   0.004097     0.032750    0.975411  0.017775
#  Holiday_Season           0.001093     0.000000    0.479629  0.002717
#  High_Value_Order         0.000335     0.000000    0.000000  0.008239
#
#                              Month       Day  Day_Of_Week   Quarter  \
#  Order_ID                -0.008787  0.002341     0.010976 -0.009870
#  Customer_ID              0.539673  0.540463     0.000000  0.539133
#  Order_Date               1.000000  1.000000     0.975460  1.000000
#  Year                     0.002944 -0.010696     0.012240  0.003798
#  Month                    1.000000  0.011822     0.019531  0.971545
#  Day                      0.011822  1.000000     0.011020  0.012353
#  Day_Of_Week              0.019531  0.011020     1.000000  0.021262
#  Quarter                  0.971545  0.012353     0.021262  1.000000
#  Customer_Age            -0.006275 -0.000406     0.020979 -0.007452
#  Customer_Gender          0.009317  0.003249     0.010828  0.008923
#  Country                  0.014835  0.017943     0.000000  0.014243
#  City                     0.010858  0.018872     0.008065  0.010903
#  Customer_Segment         0.015808  0.007818     0.009485  0.017408
#  Product_ID               0.291213  0.283862     0.034622  0.291810
#  Product_Category         0.011629  0.018847     0.006143  0.011453
#  Product_Subcategory      0.030975  0.034059     0.005108  0.031962
#  Brand                    0.014563  0.013003     0.000000  0.012806
#  Unit_Price              -0.005074 -0.012578     0.011048 -0.005750
#  Quantity                 0.006686 -0.007178     0.010486  0.007376
#  Discount_Percent         0.012847  0.004843     0.010229  0.013143
#  Discount_Amount          0.011548 -0.009270     0.011706  0.011400
#  Coupon_Used              0.005992  0.006163     0.000000  0.005977
#  Shipping_Cost           -0.002384 -0.007414     0.012647 -0.002077
#  Tax_Amount               0.002733 -0.011798     0.015607  0.001809
#  Order_Amount            -0.002521 -0.014134     0.014996 -0.003116
#  Payment_Method           0.010488  0.011758     0.005924  0.010587
#  Device_Type              0.006008  0.008065     0.000000  0.004942
#  Traffic_Source           0.009901  0.006920     0.007067  0.010995
#  Membership_Status        0.007168  0.008388     0.000000  0.006558
#  Shipping_Method          0.007384  0.002394     0.000000  0.007545
#  Warehouse_Region         0.005256  0.017956     0.010227  0.006147
#  Delivery_Days            0.002994  0.001483     0.017813  0.000549
#  Order_Status             0.020328  0.009266     0.005626  0.020316
#  Returned                 0.009392  0.002313     0.005216  0.009811
#  Review_Rating           -0.012324  0.001215     0.018543 -0.011702
#  Customer_Lifetime_Value  0.002792 -0.011559     0.011878  0.001541
#  Profit_Margin_Percent   -0.002504  0.001930     0.009458 -0.002775
#  Profit_Amount           -0.007312 -0.014639     0.020804 -0.008154
#  Season                   0.650548  0.016849     0.010351  0.673409
#  Holiday_Season           0.324493  0.006526     0.003875  0.299161
#  High_Value_Order         0.002130  0.010650     0.000000  0.001514
#
#                           Customer_Age  Customer_Gender  ...  Delivery_Days  \
#  Order_ID                    -0.003918         0.005985  ...      -0.003359
#  Customer_ID                  0.534422         0.041805  ...       0.541616
#  Order_Date                   0.222876         0.037254  ...       0.218229
#  Year                         0.002207         0.003235  ...      -0.004446
#  Month                       -0.006275         0.009317  ...       0.002994
#  Day                         -0.000406         0.003249  ...       0.001483
#  Day_Of_Week                  0.020979         0.010828  ...       0.017813
#  Quarter                     -0.007452         0.008923  ...       0.000549
#  Customer_Age                 1.000000         0.007902  ...      -0.004039
#  Customer_Gender              0.007902         1.000000  ...       0.005970
#  Country                      0.014978         0.000000  ...       0.192559
#  City                         0.019770         0.000000  ...       0.020264
#  Customer_Segment             0.012175         0.009069  ...       0.006444
#  Product_ID                   0.287191         0.012829  ...       0.290909
#  Product_Category             0.013004         0.000000  ...       0.015386
#  Product_Subcategory          0.032340         0.000000  ...       0.028780
#  Brand                        0.013312         0.006934  ...       0.015317
#  Unit_Price                  -0.000357         0.001879  ...       0.011346
#  Quantity                    -0.007113         0.013254  ...       0.001030
#  Discount_Percent             0.003474         0.005940  ...       0.005594
#  Discount_Amount              0.001726         0.007169  ...       0.002248
#  Coupon_Used                  0.000682         0.000000  ...       0.005337
#  Shipping_Cost                0.001116         0.011668  ...      -0.442979
#  Tax_Amount                  -0.001604         0.001971  ...       0.009116
#  Order_Amount                -0.002299         0.000948  ...       0.004089
#  Payment_Method               0.016208         0.002680  ...       0.011853
#  Device_Type                  0.014090         0.009232  ...       0.002807
#  Traffic_Source               0.008483         0.000000  ...       0.007813
#  Membership_Status            0.011058         0.000000  ...       0.013182
#  Shipping_Method              0.009784         0.000000  ...       0.520194
#  Warehouse_Region             0.010357         0.003798  ...       0.019817
#  Delivery_Days               -0.004039         0.005970  ...       1.000000
#  Order_Status                 0.021273         0.012800  ...       0.008595
#  Returned                     0.001553         0.016422  ...       0.003369
#  Review_Rating                0.000888         0.015659  ...      -0.058689
#  Customer_Lifetime_Value     -0.003470         0.005561  ...       0.001687
#  Profit_Margin_Percent       -0.004467         0.000542  ...      -0.009567
#  Profit_Amount               -0.005350         0.006248  ...       0.003395
#  Season                       0.012290         0.000000  ...       0.013624
#  Holiday_Season               0.003491         0.007670  ...       0.003480
#  High_Value_Order             0.002419         0.008973  ...       0.004802
#
#                           Order_Status  Returned  Review_Rating  \
#  Order_ID                     0.007944  0.006681       0.002797
#  Customer_ID                  0.000000  0.000000       0.536293
#  Order_Date                   0.017744  0.019307       0.225337
#  Year                         0.007705  0.001243       0.005233
#  Month                        0.020328  0.009392      -0.012324
#  Day                          0.009266  0.002313       0.001215
#  Day_Of_Week                  0.005626  0.005216       0.018543
#  Quarter                      0.020316  0.009811      -0.011702
#  Customer_Age                 0.021273  0.001553       0.000888
#  Customer_Gender              0.012800  0.016422       0.015659
#  Country                      0.000000  0.000000       0.025802
#  City                         0.007978  0.000000       0.009446
#  Customer_Segment             0.014079  0.027414       0.018179
#  Product_ID                   0.035223  0.000000       0.284861
#  Product_Category             0.031219  0.064004       0.029550
#  Product_Subcategory          0.032718  0.066501       0.039394
#  Brand                        0.000000  0.000000       0.018722
#  Unit_Price                   0.008155  0.004226       0.002861
#  Quantity                     0.008360  0.000864      -0.001548
#  Discount_Percent             0.008294  0.006159       0.002041
#  Discount_Amount              0.003393  0.002248      -0.002936
#  Coupon_Used                  0.014492  0.010598       0.000074
#  Shipping_Cost                0.009760  0.002496       0.002638
#  Tax_Amount                   0.007999  0.005130       0.006336
#  Order_Amount                 0.008814  0.005362       0.003444
#  Payment_Method               0.000000  0.000000       0.007765
#  Device_Type                  0.000000  0.005817       0.009341
#  Traffic_Source               0.000000  0.000000       0.011497
#  Membership_Status            0.000000  0.000000       0.057227
#  Shipping_Method              0.000000  0.001936       0.017472
#  Warehouse_Region             0.000000  0.009030       0.013555
#  Delivery_Days                0.008595  0.003369      -0.058689
#  Order_Status                 1.000000  0.999950       0.474890
#  Returned                     0.999950  1.000000       0.474800
#  Review_Rating                0.474890  0.474800       1.000000
#  Customer_Lifetime_Value      0.012120  0.007771       0.009335
#  Profit_Margin_Percent        0.015848  0.013894      -0.009763
#  Profit_Amount                0.008144  0.001128       0.000672
#  Season                       0.007962  0.004630       0.014188
#  Holiday_Season               0.000000  0.000000       0.005471
#  High_Value_Order             0.006520  0.000000       0.001113
#
#                           Customer_Lifetime_Value  Profit_Margin_Percent  \
#  Order_ID                               -0.005001              -0.005124
#  Customer_ID                             0.538885               0.538563
#  Order_Date                              0.224832               0.217817
#  Year                                   -0.006689              -0.008499
#  Month                                   0.002792              -0.002504
#  Day                                    -0.011559               0.001930
#  Day_Of_Week                             0.011878               0.009458
#  Quarter                                 0.001541              -0.002775
#  Customer_Age                           -0.003470              -0.004467
#  Customer_Gender                         0.005561               0.000542
#  Country                                 0.022888               0.013097
#  City                                    0.022256               0.021585
#  Customer_Segment                        0.058225               0.008503
#  Product_ID                              0.286707               0.291964
#  Product_Category                        0.669041               0.404902
#  Product_Subcategory                     0.669271               0.405537
#  Brand                                   0.012233               0.018084
#  Unit_Price                              0.756279              -0.232164
#  Quantity                                0.257869               0.002418
#  Discount_Percent                       -0.061062              -0.291392
#  Discount_Amount                         0.524185              -0.248519
#  Coupon_Used                             0.046262               0.196841
#  Shipping_Cost                           0.086154               0.002557
#  Tax_Amount                              0.799547              -0.184959
#  Order_Amount                            0.861991              -0.176849
#  Payment_Method                          0.008829               0.013878
#  Device_Type                             0.010606               0.002672
#  Traffic_Source                          0.009538               0.014408
#  Membership_Status                       0.014393               0.008632
#  Shipping_Method                         0.011532               0.009365
#  Warehouse_Region                        0.009656               0.012525
#  Delivery_Days                           0.001687              -0.009567
#  Order_Status                            0.012120               0.015848
#  Returned                                0.007771               0.013894
#  Review_Rating                           0.009335              -0.009763
#  Customer_Lifetime_Value                 1.000000              -0.159812
#  Profit_Margin_Percent                  -0.159812               1.000000
#  Profit_Amount                           0.738069               0.124010
#  Season                                  0.006685               0.010143
#  Holiday_Season                          0.000403               0.003377
#  High_Value_Order                        0.633292               0.182715
#
#                           Profit_Amount    Season  Holiday_Season  \
#  Order_ID                     -0.005518  0.004097        0.001093
#  Customer_ID                   0.554689  0.032750        0.000000
#  Order_Date                    0.221964  0.975411        0.479629
#  Year                         -0.011831  0.017775        0.002717
#  Month                        -0.007312  0.650548        0.324493
#  Day                          -0.014639  0.016849        0.006526
#  Day_Of_Week                   0.020804  0.010351        0.003875
#  Quarter                      -0.008154  0.673409        0.299161
#  Customer_Age                 -0.005350  0.012290        0.003491
#  Customer_Gender               0.006248  0.000000        0.007670
#  Country                       0.021174  0.000000        0.000000
#  City                          0.021212  0.000000        0.007128
#  Customer_Segment              0.004755  0.000000        0.000000
#  Product_ID                    0.288097  0.000000        0.058975
#  Product_Category              0.598356  0.009782        0.002205
#  Product_Subcategory           0.598940  0.010157        0.000000
#  Brand                         0.015300  0.012405        0.004418
#  Unit_Price                    0.701226  0.009949        0.005132
#  Quantity                      0.293167  0.012112        0.002071
#  Discount_Percent             -0.153032  0.014336        0.000905
#  Discount_Amount               0.378123  0.005936        0.001095
#  Coupon_Used                   0.112358  0.011477        0.000000
#  Shipping_Cost                 0.097206  0.007408        0.003173
#  Tax_Amount                    0.772493  0.007384        0.001082
#  Order_Amount                  0.856363  0.007557        0.002395
#  Payment_Method                0.008011  0.007187        0.000000
#  Device_Type                   0.007363  0.000000        0.000000
#  Traffic_Source                0.021611  0.000000        0.000000
#  Membership_Status             0.010860  0.000000        0.004719
#  Shipping_Method               0.012157  0.004474        0.000000
#  Warehouse_Region              0.005202  0.004277        0.009649
#  Delivery_Days                 0.003395  0.013624        0.003480
#  Order_Status                  0.008144  0.007962        0.000000
#  Returned                      0.001128  0.004630        0.000000
#  Review_Rating                 0.000672  0.014188        0.005471
#  Customer_Lifetime_Value       0.738069  0.006685        0.000403
#  Profit_Margin_Percent         0.124010  0.010143        0.003377
#  Profit_Amount                 1.000000  0.008769        0.005944
#  Season                        0.008769  1.000000        0.222442
#  Holiday_Season                0.005944  0.222442        1.000000
#  High_Value_Order              0.614496  0.014303        0.000000
#
#                           High_Value_Order
#  Order_ID                         0.000335
#  Customer_ID                      0.000000
#  Order_Date                       0.000000
#  Year                             0.008239
#  Month                            0.002130
#  Day                              0.010650
#  Day_Of_Week                      0.000000
#  Quarter                          0.001514
#  Customer_Age                     0.002419
#  Customer_Gender                  0.008973
#  Country                          0.008476
#  City                             0.012247
#  Customer_Segment                 0.000000
#  Product_ID                       0.000000
#  Product_Category                 0.748703
#  Product_Subcategory              0.748297
#  Brand                            0.003064
#  Unit_Price                       0.711186
#  Quantity                         0.240948
#  Discount_Percent                 0.061092
#  Discount_Amount                  0.450617
#  Coupon_Used                      0.044121
#  Shipping_Cost                    0.086360
#  Tax_Amount                       0.646871
#  Order_Amount                     0.694498
#  Payment_Method                   0.000000
#  Device_Type                      0.011863
#  Traffic_Source                   0.000000
#  Membership_Status                0.000000
#  Shipping_Method                  0.014551
#  Warehouse_Region                 0.007557
#  Delivery_Days                    0.004802
#  Order_Status                     0.006520
#  Returned                         0.000000
#  Review_Rating                    0.001113
#  Customer_Lifetime_Value          0.633292
#  Profit_Margin_Percent            0.182715
#  Profit_Amount                    0.614496
#  Season                           0.014303
#  Holiday_Season                   0.000000
#  High_Value_Order                 1.000000
#
#  [41 rows x 41 columns],
#  'ax': <Axes: >}

# %%
print(rf_model)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Order_Date', 'Day_Of_Week',
#                                                    'Customer_Gender', 'Country',
#                                                    'City', 'Customer_Segment',
#                                                    'Product_Category',
#                                                    'Product_Subcategory',
#                                                    'Brand', 'Coupon_Used',
#                                                    'Payment_Method',
#                                                    'Device_Type',
#                                                    'Traffic_Source',
#                                                    'Membership_Status',
#                                                    'Shipping_Method',
#                                                    'Warehouse_Region',
#                                                    'Order_Status', 'Returned',
#                                                    'Season',
#                                                    'Holiday_Season'])])),
#                 ('classifier',
#                  RandomForestClassifier(n_estimators=200, random_state=42))])

# %%
rf_model.named_steps["classifier"].feature_importances_
# Out:
# array([5.75523603e-06, 7.42747121e-05, 1.50028941e-05, ...,
#        5.39560668e-03, 6.05400868e-03, 1.49251067e-01], shape=(1602,))

# %%
print(rf_model.named_steps)
# Out:
# {'preprocessor': ColumnTransformer(remainder='passthrough',
#                   transformers=[('cat', OneHotEncoder(handle_unknown='ignore'),
#                                  ['Order_Date', 'Day_Of_Week',
#                                   'Customer_Gender', 'Country', 'City',
#                                   'Customer_Segment', 'Product_Category',
#                                   'Product_Subcategory', 'Brand', 'Coupon_Used',
#                                   'Payment_Method', 'Device_Type',
#                                   'Traffic_Source', 'Membership_Status',
#                                   'Shipping_Method', 'Warehouse_Region',
#                                   'Order_Status', 'Returned', 'Season',
#                                   'Holiday_Season'])]), 'classifier': RandomForestClassifier(n_estimators=200, random_state=42)}

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Get feature names after preprocessing
feature_names = rf_model.named_steps["preprocessor"].get_feature_names_out()

# Get feature importance
importances = rf_model.named_steps["classifier"].feature_importances_

# Create DataFrame
feature_importance = pd.DataFrame({
    "Feature": feature_names,
    "Importance": importances
})

# Sort
feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

display(feature_importance.head(20))
# Out:
#                                    Feature  Importance
# 1598                 remainder__Tax_Amount    0.163214
# 1601    remainder__Customer_Lifetime_Value    0.149251
# 1593                 remainder__Unit_Price    0.138295
# 1497     cat__Product_Category_Electronics    0.089295
# 1596            remainder__Discount_Amount    0.065747
# 1594                   remainder__Quantity    0.026883
# 1503  cat__Product_Subcategory_Accessories    0.019573
# 1526       cat__Product_Subcategory_Mobile    0.019550
# 1523       cat__Product_Subcategory_Laptop    0.017598
# 1522   cat__Product_Subcategory_Headphones    0.017102
# 1499       cat__Product_Category_Groceries    0.014731
# 1500  cat__Product_Category_Home & Kitchen    0.011185
# 1597              remainder__Shipping_Cost    0.010629
# 1595           remainder__Discount_Percent    0.010246
# 1592               remainder__Customer_Age    0.006559
# 1600              remainder__Review_Rating    0.006054
# 1590                        remainder__Day    0.005975
# 1495          cat__Product_Category_Beauty    0.005597
# 1599              remainder__Delivery_Days    0.005396
# 1498         cat__Product_Category_Fashion    0.004804

# %% [markdown]
# #### Top 20 encoded features.

# %%
top20 = feature_importance.head(20)

plt.figure(figsize=(12,8))

plt.barh(
    top20["Feature"][::-1],
    top20["Importance"][::-1]
)

plt.xlabel("Importance")
plt.title("Top 20 Feature Importance - Random Forest")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Aggregated feature importance (correctly aggregated).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Get feature names after preprocessing
feature_names = rf_model.named_steps["preprocessor"].get_feature_names_out()

# Get feature importances
importances = rf_model.named_steps["classifier"].feature_importances_

# Create DataFrame
fi = pd.DataFrame({
    "Feature": feature_names,
    "Importance": importances
})

# Function to recover original feature name
def get_original_feature(feature):
    # OneHotEncoded categorical features
    if feature.startswith("cat__"):
        return feature.replace("cat__", "").split("_")[0]

    # Numerical features (passed through)
    elif feature.startswith("remainder__"):
        return feature.replace("remainder__", "")

    return feature

# Aggregate importances
fi["Original_Feature"] = fi["Feature"].apply(get_original_feature)

feature_importance = (
    fi.groupby("Original_Feature", as_index=False)["Importance"]
      .sum()
      .sort_values(by="Importance", ascending=False)
)

# Display
display(feature_importance)

# Plot
plt.figure(figsize=(10,8))

plt.barh(
    feature_importance["Original_Feature"][::-1],
    feature_importance["Importance"][::-1]
)

plt.xlabel("Feature Importance")
plt.title("Aggregated Feature Importance - Random Forest")

plt.tight_layout()
plt.show()
# Out:
#            Original_Feature  Importance
# 17                  Product    0.246044
# 25               Tax_Amount    0.163214
# 6   Customer_Lifetime_Value    0.149251
# 27               Unit_Price    0.138295
# 10          Discount_Amount    0.065747
# 15                    Order    0.052827
# 18                 Quantity    0.026883
# 7                       Day    0.014083
# 24            Shipping_Cost    0.010629
# 2                   Country    0.010613
# 0                     Brand    0.010354
# 1                      City    0.010341
# 11         Discount_Percent    0.010246
# 4                  Customer    0.010207
# 16                  Payment    0.008022
# 26                  Traffic    0.008002
# 28                Warehouse    0.007078
# 5              Customer_Age    0.006559
# 21            Review_Rating    0.006054
# 22                   Season    0.005439
# 13               Membership    0.005399
# 8             Delivery_Days    0.005396
# 23                 Shipping    0.005248
# 3                    Coupon    0.004862
# 14                    Month    0.004759
# 9                    Device    0.004136
# 29                     Year    0.003430
# 19                  Quarter    0.003018
# 12                  Holiday    0.002278
# 20                 Returned    0.001587

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

print(label_encoder.classes_)
# Out:
# [0 1]

# %%
xgb_model = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", XGBClassifier(
        n_estimators=200,
        max_depth=6,
        learning_rate=0.1,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42,
        eval_metric="logloss"
    ))
])

# %%
xgb_model.fit(X_train, y_train_encoded)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Order_Date', 'Day_Of_Week',
#                                                    'Customer_Gender', 'Country',
#                                                    'City', 'Customer_Segment',
#                                                    'Product_Category',
#                                                    'Product_Subcategory',
#                                                    'Brand', 'Coupon_Used',
#                                                    'Payment_Method',
#                                                    'Device_Type',
#                                                    'Traffic_Source',
#                                                    'Membership_Status',
#                                                    'Sh...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.1,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=6, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=200, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
y_pred_xgb = xgb_model.predict(X_test)

# %%
y_pred_labels = label_encoder.inverse_transform(y_pred_xgb)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(f"Accuracy: {accuracy_score(y_test, y_pred_labels):.4f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_labels))
# Out:
# Accuracy: 0.9973
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4500
#            1       0.99      0.99      0.99      1500
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_labels)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=label_encoder.classes_
)

disp.plot(cmap="Blues")
plt.title("Confusion Matrix - XGBoost")
plt.show()

# %%
import pandas as pd

feature_names = xgb_model.named_steps["preprocessor"].get_feature_names_out()

importances = xgb_model.named_steps["classifier"].feature_importances_

feature_importance = pd.DataFrame({
    "Feature": feature_names,
    "Importance": importances
}).sort_values(by="Importance", ascending=False)

feature_importance.head(20)
# Out:
#                                    Feature  Importance
# 1598                 remainder__Tax_Amount    0.425905
# 1601    remainder__Customer_Lifetime_Value    0.070824
# 1593                 remainder__Unit_Price    0.062751
# 1497     cat__Product_Category_Electronics    0.055128
# 1594                   remainder__Quantity    0.035932
# 1595           remainder__Discount_Percent    0.016396
# 1596            remainder__Discount_Amount    0.015296
# 1546                  cat__Coupon_Used_Yes    0.011988
# 1545                   cat__Coupon_Used_No    0.010074
# 1555               cat__Device_Type_Tablet    0.007196
# 1496           cat__Product_Category_Books    0.007008
# 1500  cat__Product_Category_Home & Kitchen    0.006798
# 1522   cat__Product_Subcategory_Headphones    0.006420
# 683             cat__Order_Date_2024-11-14    0.005985
# 1569         cat__Shipping_Method_Standard    0.005814
# 1526       cat__Product_Subcategory_Mobile    0.005623
# 1523       cat__Product_Subcategory_Laptop    0.005608
# 1472                   cat__Country_Canada    0.005481
# 1597              remainder__Shipping_Cost    0.004811
# 1476                 cat__Country_Pakistan    0.004270

# %%
top20 = feature_importance.head(20)

plt.figure(figsize=(12, 8))
plt.barh(top20["Feature"][::-1], top20["Importance"][::-1])
plt.xlabel("Importance")
plt.title("Top 20 Feature Importance - XGBoost")
plt.tight_layout()
plt.show()

# %%
X_train.columns
# Out:
# Index(['Order_Date', 'Year', 'Month', 'Day', 'Day_Of_Week', 'Quarter',
#        'Customer_Age', 'Customer_Gender', 'Country', 'City',
#        'Customer_Segment', 'Product_Category', 'Product_Subcategory', 'Brand',
#        'Unit_Price', 'Quantity', 'Discount_Percent', 'Discount_Amount',
#        'Coupon_Used', 'Shipping_Cost', 'Tax_Amount', 'Payment_Method',
#        'Device_Type', 'Traffic_Source', 'Membership_Status', 'Shipping_Method',
#        'Warehouse_Region', 'Delivery_Days', 'Order_Status', 'Returned',
#        'Review_Rating', 'Customer_Lifetime_Value', 'Season', 'Holiday_Season'],
#       dtype='str')

# %%
print(X_train.columns.tolist())
# Out:
# ['Order_Date', 'Year', 'Month', 'Day', 'Day_Of_Week', 'Quarter', 'Customer_Age', 'Customer_Gender', 'Country', 'City', 'Customer_Segment', 'Product_Category', 'Product_Subcategory', 'Brand', 'Unit_Price', 'Quantity', 'Discount_Percent', 'Discount_Amount', 'Coupon_Used', 'Shipping_Cost', 'Tax_Amount', 'Payment_Method', 'Device_Type', 'Traffic_Source', 'Membership_Status', 'Shipping_Method', 'Warehouse_Region', 'Delivery_Days', 'Order_Status', 'Returned', 'Review_Rating', 'Customer_Lifetime_Value', 'Season', 'Holiday_Season']

# %%
temp = df.copy()

temp["High_Value_Order"] = temp["High_Value_Order"].map({
    "No": 0,
    "Yes": 1
})

corr_features = [
    "Tax_Amount",
    "Customer_Lifetime_Value",
    "Unit_Price",
    "Quantity",
    "Discount_Amount",
    "High_Value_Order"
]

temp[corr_features].corr()
# Out:
#                          Tax_Amount  Customer_Lifetime_Value  Unit_Price  \
# Tax_Amount                 1.000000                 0.799547    0.795631
# Customer_Lifetime_Value    0.799547                 1.000000    0.756279
# Unit_Price                 0.795631                 0.756279    1.000000
# Quantity                   0.271875                 0.257869   -0.006856
# Discount_Amount            0.641471                 0.524185    0.601403
# High_Value_Order           0.646871                 0.633292    0.711186
#
#                          Quantity  Discount_Amount  High_Value_Order
# Tax_Amount               0.271875         0.641471          0.646871
# Customer_Lifetime_Value  0.257869         0.524185          0.633292
# Unit_Price              -0.006856         0.601403          0.711186
# Quantity                 1.000000         0.200512          0.240948
# Discount_Amount          0.200512         1.000000          0.450617
# High_Value_Order         0.240948         0.450617          1.000000

# %%
df.groupby("High_Value_Order")["Tax_Amount"].describe()
# Out:
#                     count       mean        std    min    25%    50%     75%  \
# High_Value_Order
# No                22499.0  10.632398   8.609686   0.26   4.10   8.08   14.71
# Yes                7501.0  84.668208  74.105585  10.98  38.52  60.01  104.06
#
#                       max
# High_Value_Order
# No                  59.39
# Yes               1043.16

# %%
original_df[
    (original_df["Order_Amount"] >= 387) &
    (original_df["Order_Amount"] <= 390)
][["Order_Amount", "High_Value_Order"]].sort_values("Order_Amount")
# Out:
#        Order_Amount High_Value_Order
# 4708         387.01               No
# 3718         387.06               No
# 12479        387.06               No
# 22997        387.06               No
# 6485         387.14               No
# 5859         387.19               No
# 22461        387.21               No
# 20125        387.25               No
# 7463         387.26               No
# 15963        387.27               No
# 28999        387.32               No
# 13928        387.33               No
# 3995         387.39               No
# 18666        387.41               No
# 12829        387.51               No
# 5909         387.52               No
# 17601        387.73               No
# 28669        387.77               No
# 10392        387.97               No
# 22388        388.15               No
# 2402         388.16               No
# 9852         388.17               No
# 8973         388.19              Yes
# 6070         388.19              Yes
# 27023        388.33              Yes
# 7953         388.38              Yes
# 17436        388.56              Yes
# 11137        388.57              Yes
# 8562         388.65              Yes
# 29788        388.69              Yes
# 3956         388.87              Yes
# 4581         388.96              Yes
# 307          388.98              Yes
# 25717        389.05              Yes
# 13939        389.06              Yes
# 22097        389.06              Yes
# 10721        389.08              Yes
# 6776         389.14              Yes
# 21879        389.15              Yes
# 22147        389.18              Yes
# 5313         389.21              Yes
# 14837        389.23              Yes
# 26291        389.38              Yes
# 29636        389.45              Yes
# 23572        389.45              Yes
# 17826        389.53              Yes
# 26283        389.55              Yes
# 1319         389.56              Yes
# 9258         389.58              Yes
# 15955        389.67              Yes
# 11364        389.68              Yes
# 19555        389.73              Yes
# 20810        389.76              Yes
# 14177        389.83              Yes
# 9117         389.89              Yes
# 1482         389.90              Yes
# 7616         389.93              Yes
# 27970        389.98              Yes
# 12689        389.99              Yes

# %%
quartiles = original_df["Order_Amount"].quantile([0.25, 0.50, 0.75])

print(quartiles)
# Out:
# 0.25     82.9475
# 0.50    171.0300
# 0.75    388.1900
# Name: Order_Amount, dtype: float64

# %%
import matplotlib.pyplot as plt

threshold = original_df["Order_Amount"].quantile(0.75)

plt.figure(figsize=(10,6))

plt.hist(original_df["Order_Amount"], bins=50)

plt.axvline(
    threshold,
    color="red",
    linestyle="--",
    linewidth=2,
    label=f"75th Percentile = {threshold:.2f}"
)

plt.xlabel("Order Amount")
plt.ylabel("Frequency")
plt.title("Distribution of Order Amount")
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,2))

plt.boxplot(original_df["Order_Amount"], vert=False)

plt.title("Boxplot of Order Amount")
plt.xlabel("Order Amount")

plt.show()
# Out:
# C:\Users\srava\AppData\Local\Temp\ipykernel_9056\2975580715.py:3: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(original_df["Order_Amount"], vert=False)

# %%
threshold = original_df["Order_Amount"].quantile(0.75)

check = (
    (original_df["Order_Amount"] >= threshold)
    == (original_df["High_Value_Order"] == "Yes")
)

print("Rows matching threshold rule:", check.sum())
print("Total rows:", len(check))
print("Match Percentage:", check.mean() * 100)
# Out:
# Rows matching threshold rule: 30000
# Total rows: 30000
# Match Percentage: 100.0

# %%
# %who
# Out:
# ColumnTransformer	 ConfusionMatrixDisplay	 LabelEncoder	 OneHotEncoder	 Pipeline	 RandomForestClassifier	 X	 XGBClassifier	 X_test
# X_train	 accuracy	 accuracy_score	 associations	 categorical_cols	 check	 classification_report	 cm	 confusion_matrix
# corr_features	 df	 disp	 f1_score	 feature_importance	 feature_names	 fi	 get_original_feature	 importance
# importance_df	 importances	 label_encoder	 np	 numerical_cols	 original_df	 pd	 plt	 preprocessor
# quartiles	 rf	 rf_model	 sns	 temp	 threshold	 top20	 train_test_split	 xgb_model
# y	 y_encoded	 y_pred	 y_pred_labels	 y_pred_xgb	 y_test	 y_test_encoded	 y_train	 y_train_encoded

# %%
# %whos
# Out:
# Variable                 Type                      Data/Info
# ------------------------------------------------------------
# ColumnTransformer        ABCMeta                   <class 'sklearn.compose._<...>ormer.ColumnTransformer'>
# ConfusionMatrixDisplay   type                      <class 'sklearn.metrics._<...>.ConfusionMatrixDisplay'>
# LabelEncoder             type                      <class 'sklearn.preproces<...>ing._label.LabelEncoder'>
# OneHotEncoder            type                      <class 'sklearn.preproces<...>_encoders.OneHotEncoder'>
# Pipeline                 ABCMeta                   <class 'sklearn.pipeline.Pipeline'>
# RandomForestClassifier   ABCMeta                   <class 'sklearn.ensemble.<...>.RandomForestClassifier'>
# X                        DataFrame                 Shape: (30000, 34)
# XGBClassifier            type                      <class 'xgboost.sklearn.XGBClassifier'>
# X_test                   DataFrame                 Shape: (6000, 34)
# X_train                  DataFrame                 Shape: (24000, 34)
# accuracy                 float                     0.97
# accuracy_score           function                  <function accuracy_score at 0x000001968FDE2DE0>
# associations             function                  <function associations at 0x00000196945FFC40>
# categorical_cols         list                      n=20
# check                    Series                    Shape: (30000,)
# classification_report    function                  <function classification_<...>rt at 0x000001968FDF82C0>
# cm                       ndarray                   2x2: 4 elems, type `int64`, 32 bytes
# confusion_matrix         function                  <function confusion_matrix at 0x000001968FDE2F20>
# corr_features            list                      n=6
# df                       DataFrame                 Shape: (30000, 35)
# disp                     ConfusionMatrixDisplay    <sklearn.metrics._plot.co<...>ct at 0x00000196944DAD50>
# f1_score                 function                  <function f1_score at 0x000001968FDE36A0>
# feature_importance       DataFrame                 Shape: (1602, 2)
# feature_names            ndarray                   1602: 1602 elems, type `object`, 12816 bytes
# fi                       DataFrame                 Shape: (1602, 3)
# get_original_feature     function                  <function get_original_fe<...>re at 0x0000019693665B20>
# importance               ndarray                   1602: 1602 elems, type `float64`, 12816 bytes
# importance_df            DataFrame                 Shape: (1602, 2)
# importances              ndarray                   1602: 1602 elems, type `float32`, 6408 bytes
# label_encoder            LabelEncoder              LabelEncoder()
# np                       module                    <module 'numpy' from 'd:\<...>ges\\numpy\\__init__.py'>
# numerical_cols           list                      n=14
# original_df              DataFrame                 Shape: (30000, 41)
# pd                       module                    <module 'pandas' from 'd:<...>es\\pandas\\__init__.py'>
# plt                      module                    <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# preprocessor             ColumnTransformer         ColumnTransformer(remaind<...>     'Holiday_Season'])])
# quartiles                Series                    Shape: (3,)
# rf                       RandomForestClassifier    RandomForestClassifier(n_<...>ors=200, random_state=42)
# rf_model                 Pipeline                  Pipeline(steps=[('preproc<...>=200, random_state=42))])
# sns                      module                    <module 'seaborn' from 'd<...>s\\seaborn\\__init__.py'>
# temp                     DataFrame                 Shape: (30000, 35)
# threshold                float64                   388.19
# top20                    DataFrame                 Shape: (20, 2)
# train_test_split         function                  <function train_test_split at 0x0000019692398400>
# xgb_model                Pipeline                  Pipeline(steps=[('preproc<...>rallel_tree=None, ...))])
# y                        Series                    Shape: (30000,)
# y_encoded                ndarray                   30000: 30000 elems, type `int64`, 240000 bytes (234.375 kb)
# y_pred                   ndarray                   6000: 6000 elems, type `int64`, 48000 bytes
# y_pred_labels            ndarray                   6000: 6000 elems, type `int64`, 48000 bytes
# y_pred_xgb               ndarray                   6000: 6000 elems, type `int64`, 48000 bytes
# y_test                   ndarray                   6000: 6000 elems, type `int64`, 48000 bytes
# y_test_encoded           ndarray                   6000: 6000 elems, type `int64`, 48000 bytes
# y_train                  ndarray                   24000: 24000 elems, type `int64`, 192000 bytes (187.5 kb)
# y_train_encoded          ndarray                   24000: 24000 elems, type `int64`, 192000 bytes (187.5 kb)

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(
    xgb_model,
    X_test,
    y_test_encoded
)

# %%
import os
print(os.getcwd())
# Out:
# d:\CDAC PGCP BDA Projects\shopstream\notebooks

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(
    xgb_model,
    X,
    y_encoded,
    cv=5,
    scoring="f1"
)

print(scores)
print("Mean F1:", scores.mean())
# Out:
# [0.98933333 0.98997996 0.99100899 0.992      0.99067288]
# Mean F1: 0.9905990338011337

# %%
param_dist = {
    "classifier__n_estimators": [100, 200, 300],
    "classifier__max_depth": [3, 5, 7, 9],
    "classifier__learning_rate": [0.01, 0.05, 0.1, 0.2],
    "classifier__subsample": [0.8, 0.9, 1.0],
    "classifier__colsample_bytree": [0.8, 0.9, 1.0],
    "classifier__min_child_weight": [1, 3, 5]
}

# %%
from sklearn.model_selection import RandomizedSearchCV

random_search = RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=param_dist,
    n_iter=2,
    cv=2,
    scoring="f1",
    random_state=42,
    n_jobs=1,
    error_score="raise",
    verbose=2
)

random_search.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END classifier__colsample_bytree=1.0, classifier__learning_rate=0.1, classifier__max_depth=5, classifier__min_child_weight=5, classifier__n_estimators=100, classifier__subsample=0.9; total time=   0.2s
# [CV] END classifier__colsample_bytree=1.0, classifier__learning_rate=0.1, classifier__max_depth=5, classifier__min_child_weight=5, classifier__n_estimators=100, classifier__subsample=0.9; total time=   0.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.2, classifier__max_depth=9, classifier__min_child_weight=5, classifier__n_estimators=200, classifier__subsample=1.0; total time=   0.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__learning_rate=0.2, classifier__max_depth=9, classifier__min_child_weight=5, classifier__n_estimators=200, classifier__subsample=1.0; total time=   0.3s
# RandomizedSearchCV(cv=2, error_score='raise',
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('cat',
#                                                                                OneHotEncoder(handle_unknown='ignore'),
#                                                                                ['Order_Date',
#                                                                                 'Day_Of_Week',
#                                                                                 'Customer_Gender',
#                                                                                 'Country',
#                                                                                 'City',
#                                                                                 'Customer_Segment',
#                                                                                 'Product_Category',
#                                                                                 'Product_Subcategory',
#                                                                                 'Brand',
#                                                                                 'Coupon_Used',
#                                                                                 'Payment_Method',...
#                                                             num_parallel_tree=None, ...))]),
#                    n_iter=2, n_jobs=1,
#                    param_distributions={'classifier__colsample_bytree': [0.8,
#                                                                          0.9,
#                                                                          1.0],
#                                         'classifier__learning_rate': [0.01,
#                                                                       0.05, 0.1,
#                                                                       0.2],
#                                         'classifier__max_depth': [3, 5, 7, 9],
#                                         'classifier__min_child_weight': [1, 3,
#                                                                          5],
#                                         'classifier__n_estimators': [100, 200,
#                                                                      300],
#                                         'classifier__subsample': [0.8, 0.9,
#                                                                   1.0]},
#                    random_state=42, scoring='f1', verbose=2)

# %%
print("Best Parameters:")
print(random_search.best_params_)

print("\nBest CV F1 Score:")
print(random_search.best_score_)
# Out:
# Best Parameters:
# {'classifier__subsample': 1.0, 'classifier__n_estimators': 200, 'classifier__min_child_weight': 5, 'classifier__max_depth': 9, 'classifier__learning_rate': 0.2, 'classifier__colsample_bytree': 0.9}
#
# Best CV F1 Score:
# 0.985541284456952

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
)

best_model = random_search.best_estimator_

y_pred = best_model.predict(X_test)

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.9973333333333333
# Precision: 0.9946666666666667
# Recall   : 0.9946666666666667
# F1 Score : 0.9946666666666667

# %%
import joblib

# %%
# joblib.dump(random_search.best_estimator_, "../ml/models/high_value_order_xgb_pipeline.pkl")

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

rf_pred = rf_model.predict(X_test)

rf_accuracy = accuracy_score(y_test, rf_pred)
rf_precision = precision_score(y_test, rf_pred)
rf_recall = recall_score(y_test, rf_pred)
rf_f1 = f1_score(y_test, rf_pred)

# %%
xgb_accuracy = accuracy_score(y_test_encoded, y_pred_xgb)
xgb_precision = precision_score(y_test_encoded, y_pred_xgb)
xgb_recall = recall_score(y_test_encoded, y_pred_xgb)
xgb_f1 = f1_score(y_test_encoded, y_pred_xgb)

# %%
import pandas as pd

comparison = pd.DataFrame({
    "Model": ["Random Forest", "XGBoost"],
    "Accuracy": [rf_accuracy, xgb_accuracy],
    "Precision": [rf_precision, xgb_precision],
    "Recall": [rf_recall, xgb_recall],
    "F1 Score": [rf_f1, xgb_f1]
})

comparison = comparison.sort_values(by="F1 Score", ascending=False)
comparison
# Out:
#            Model  Accuracy  Precision    Recall  F1 Score
# 1        XGBoost  0.997333   0.994667  0.994667  0.994667
# 0  Random Forest  0.970000   0.959610  0.918667  0.938692

# %%
from sklearn.metrics import accuracy_score, f1_score

# Training predictions
train_pred = best_model.predict(X_train)

# Test predictions
test_pred = best_model.predict(X_test)

print("Train Accuracy:", accuracy_score(y_train, train_pred))
print("Test Accuracy :", accuracy_score(y_test, test_pred))

print("Train F1:", f1_score(y_train, train_pred))
print("Test F1 :", f1_score(y_test, test_pred))
# Out:
# Train Accuracy: 1.0
# Test Accuracy : 0.9973333333333333
# Train F1: 1.0
# Test F1 : 0.9946666666666667
